# %%
import sys
from pprint import pprint
import time

# %%
text = get_text()

print "  text[]  (size = %10d bytes)" % sys.getsizeof(text)
# pprint(text)
# Out:
#   text[]  (size =      24283 bytes)

# %%
t0 = time.clock()
suffix = suffix_array(text)
t = (time.clock() - t0) * 10

print "suffix[]  (size = %10d bytes, exec_time = %5f)" % (sys.getsizeof(suffix), t)
# pprint(suffix)
# Out:
# suffix[]  (size =     194064 bytes, exec_time = 1.453408)

# %%
t0 = time.clock()
lcp = longest_common_prefix(suffix)
t = (time.clock() - t0) * 10
print "   lcp[]  (size = %10d bytes, exec_time = %5f)" % (sys.getsizeof(lcp), t)
# pprint(lcp)
# Out:
#    lcp[]  (size =     194064 bytes, exec_time = 0.540108)

# %%
t0 = time.clock()
count = suffix_counts(suffix)
t = (time.clock() - t0) * 10
print " count[]  (size = %10d bytes, exec_time = %5f)" % (sys.getsizeof(count), t)
# pprint(count)
# Out:
#  count[]  (size =     194064 bytes, exec_time = 2.056260)

# %%
max_lcp, i = max_value_and_index(lcp)
phrase = suffix[i][:lcp[i]]
print "longest repeated phrase = %d X '%s' " % (count[i], phrase)
# Out:
# longest repeated phrase = 2 X ' television wall displaying extensive selection televisions related products, many stores contain movie theater room, complete theaterstyle seats, showcases Company's home theater products. '

# %%
max_count, i = max_value_and_index(count)
phrase = suffix[i][:lcp[i]]
print "   most repeated phrase = %d X '%s' " % (max_count, phrase)

# print "  # lpc suffix"
# for i in xrange(len(text)):
# 	print "%3d %3d '%s'" % (count[i], lcp[i], suffix[i][:lcp[i]])
# Out:
#    most repeated phrase = 2339 X 'e'

# %%
def suffix_array(text):
	suffix = [0]*len(text)
	for i in xrange(len(text)):
		suffix[i]  = text[i:]
	suffix.sort()
	return suffix


def longest_common_prefix(suffix):
	lcp = [0]*len(suffix)
	previous = ""
	for i in xrange(len(text)):
		count = 0
		current = suffix[i]
		max_count = min(len(current), len(previous))
		count = 0
		for j in xrange(max_count):
			if current[j] != previous[j]:
				break
			count +=1
	
		lcp[i] = count
		previous = current		
	return lcp


def leftmost(A, W):
	length = len(W)
	if W <= A[0][0:length]:
		return 0
	elif W > A[-1]:
		return len(A)-1
	else: 
		L = 0
		R = len(A)-1
		
		# print "(  L,   M,   R)"
		# print "(%3d, %3d, %3d)" % (L, (L + R)//2, R)		
		while R-L > 1:
			M = (L + R)//2
			if W <= A[M][0:length]: 
				R = M
			else: 
				L = M
			# print "(%3d, %3d, %3d)" % (L, M, R)
		return R


def rightmost(A, W):
	length = len(W)
	if W >= A[-1][0:length]:
		return len(A)-1
	elif W < A[0]:
		return 0
	else: 
		L = 0
		R = len(A)-1
		# print "(  L,   M,   R)"
		# print "(%3d, %3d, %3d)" % (L, (L + R)//2, R)		
		while R-L > 1:
			M = (L + R)//2
			if W >= A[M][0:length]: 
				L = M
			else: 
				R = M
			# print "(%3d, %3d, %3d)" % (L, M, R)
		return L


def max_value_and_index(L):
	# todo: have the return a list in case of ties
	max_value = L[0]
	max_index = 0
	i = 0
	for x in L:
		if x > max_value:
			max_value = x
			max_index = i
		i += 1
	return (max_value, max_index)


def suffix_count_of_word(suffix, W):
	if (not W):
		return 0
	return (rightmost(suffix, W) - leftmost(suffix, W)) + 1

	
def suffix_counts(suffix):
	count = [0]*len(suffix)
	for i in xrange(len(suffix)):
		count[i] = suffix_count_of_word(suffix, suffix[i][0:lcp[i]])
		# print "%10d %10d '%s'" % (count[i], lcp[i], suffix[i][0:lcp[i]])
	return count


def left_maximal(text, suffix, W1):
	c1 = suffix_count_of_word(suffix, W1)
	W2 = text[:-len(W)]
	c2 = suffix_count_of_word(suffix, W2)
	print " c2 = (%d, '%s') and c1 = (%d, '%s')  " %  (c2, W2, c1, W1)
	return c2 < c1 


def get_text():
	input_filename = 'C:/Users/rohit/Documents/IPO Project/business/0001060390_business.txt'
	with open(input_filename, 'r') as f:
		text = f.read().strip()
	f.closed
	# text = "we do big things. blah blah we do big things."
	# text = "abcd xxxx abcd yyyy abcd"
	# text = "abcd abcd"	
	return text



def q(s):
	return "'" + s + "'"


def wcount(text):
	"returns the number of words"
	import re
	text = re.sub('[^\w&^\d]', ' ', text)
	return len(text.split())

def print_maximal_phrases(suffix, lcp, count):
	prev = ""
	print '%s\t%s\t%s' % ("count", "numberwords", "phrase")
	for i in xrange(len(suffix)):
		w = suffix[i][:lcp[i]]
		if w.strip() == prev.strip():
			continue
		if w[:1].isalnum() or w[-1:].isalnum(): 
			continue
		
		s = suffix[i]
		left_suffix = text[-(len(s)+1):]
		j = leftmost(suffix, left_suffix)
		left_suffix = left_suffix[:lcp[j]]
		if count[j] != 0 and lcp[j] <= lcp[i]:
			print '%d\t%d\t%s' % (count[i], wcount(w), q(w))
			prev = w

# %%
print_maximal_phrases(suffix, lcp, count)
# Out:
# count	numberwords	phrase
# 2	2	' "Wise Buys" '
# 6	0	' $'
# 27	0	' ('
# 5	1	' (ii) '
# 4	1	' (iv) '
# 3	1	' (v) '
# 2	1	' (vi) '
# 2	1	' 15,'
# 2	1	' 1978 '
# 3	1	' 1986 '
# 2	1	' 1987 '
# 4	1	' 1990 '
# 5	1	' 1993 '
# 8	1	' 1995 '
# 7	1	' 1996 '
# 12	1	' 1997 '
# 3	2	' 1997, Company '
# 10	1	' 1998 '
# 3	1	' 1998, '
# 3	2	' 30, 1997 '
# 5	2	' 31, 1998 '
# 2	1	' 36 '
# 2	1	' 38 '
# 2	1	' 39 '
# 2	2	' ACQUISITION OF '
# 4	1	' AND '
# 4	1	' Acquisition '
# 2	3	' Acquisition. Like Tweeter '
# 2	1	' As '
# 2	2	' Atlanta, Georgia '
# 2	1	' Audio '
# 9	3	' Automatic Price Protection '
# 3	4	' Automatic Price Protection program '
# 2	3	' Bryn Mawr Acquisition '
# 9	2	' Bryn Mawr '
# 3	3	' Bryn Mawr stores '
# 2	3	' Bryn Mawr stores. '
# 3	2	' Bryn Mawr, '
# 14	1	' Buys '
# 3	1	' Buys" '
# 2	2	' Canton, Massachusetts '
# 2	2	' Company (i) '
# 3	1	' Company ('
# 4	2	' Company also '
# 4	2	' Company currently '
# 80	1	' Company '
# 56	2	' Company's '
# 9	3	' Company's stores '
# 2	4	' Company's stores feature '
# 9	3	' Company's stores '
# 2	4	' ENDED SIX MONTHS ENDED '
# 2	2	' HIFI BUYS '
# 2	3	' HiFi Buys Acquisition '
# 12	2	' HiFi Buys '
# 2	3	' HiFi Buys stores '
# 11	1	' In '
# 2	2	' In addition '
# 11	1	' March '
# 4	3	' March 31, 1998 '
# 2	4	' March 31, 1998. The '
# 2	1	' Massachusetts. '
# 3	1	' New '
# 4	1	' OF '
# 2	2	' STORE FORMAT '
# 14	3	' The Company believes '
# 3	3	' The Company currently '
# 2	4	' The Company intends open '
# 44	2	' The Company '
# 3	3	' The Company utilizes '
# 16	3	' The Company's '
# 3	4	' The Company's stores '
# 3	2	' Tweeter stores '
# 2	2	' Tweeter stores, '
# 2	1	' Video '
# 2	2	' Wise Buys '
# 2	2	' YEAR ENDED '
# 2	4	' YEAR OPENED YEAR OPENED '
# 2	2	' Year 2000 '
# 3	1	' accounted '
# 5	1	' acquired '
# 3	1	' acquisition '
# 3	1	' acquisitions '
# 2	1	' acquisitions, ('
# 4	1	' additional '
# 2	1	' adjusted '
# 2	1	' administrative '
# 3	1	' adopted '
# 2	1	' advertisements '
# 14	1	' advertising '
# 2	1	' advertising, '
# 2	2	' allow customer '
# 5	1	' allows '
# 6	1	' also '
# 2	9	' among earliest retailers offer new product innovations behalf manufacturers. '
# 5	1	' among '
# 3	1	' and, '
# 2	1	' applications '
# 6	1	' approximately '
# 2	2	' architecturally acoustically '
# 14	1	' audio '
# 3	2	' audio products. '
# 14	1	' audio '
# 7	2	' audio video '
# 6	1	' average '
# 2	1	' basis '
# 18	1	' believes '
# 2	1	' benefits '
# 2	1	' button,'
# 9	1	' car '
# 3	2	' car stereo '
# 3	1	' cassette '
# 2	1	' category '
# 3	1	' center '
# 3	2	' centers. The '
# 3	1	' changes '
# 2	1	' compatible '
# 11	1	' competitive '
# 3	2	' competitive pricing '
# 2	11	' competitor within 25 miles store advertises lower price within 30 days '
# 3	1	' competitors '
# 2	1	' competitors, '
# 2	1	' concerning '
# 8	2	' consumer electronics '
# 2	3	' consumer electronics products '
# 14	1	' consumer '
# 3	1	' contain '
# 2	1	' converting '
# 4	1	' corporate '
# 2	1	' cost '
# 3	1	' current '
# 7	1	' currently '
# 18	1	' customer '
# 2	2	' customer service '
# 18	1	' customer '
# 2	2	' customer's '
# 6	1	' customers '
# 2	2	' customers sample '
# 6	1	' customers '
# 2	1	' customers. '
# 5	1	' days '
# 2	1	' decks, '
# 2	1	' designed '
# 2	1	' developed '
# 3	1	' different '
# 3	2	' direct mail '
# 3	2	' direct marketing '
# 2	2	' disc players, '
# 2	1	' distributes '
# 2	2	' distribution center '
# 12	1	' distribution '
# 3	1	' distribution, '
# 2	1	' dollars '
# 2	1	' electronic '
# 10	1	' electronics '
# 6	1	' emphasis '
# 2	2	' emphasis promotional '
# 2	1	' emphasize '
# 3	1	' employees '
# 2	1	' enables '
# 2	1	' enhance '
# 2	1	' ensure '
# 2	1	' environment '
# 2	2	' environment. The '
# 4	3	' every day competitive '
# 2	4	' every day competitive pricing '
# 5	1	' existing '
# 2	1	' expects '
# 3	1	' extensive '
# 2	1	' facilities '
# 6	1	' facility '
# 2	2	' facility approximately '
# 3	1	' factors, '
# 3	1	' features '
# 2	3	' fiscal 1997, Company '
# 7	1	' five '
# 2	1	' focused '
# 2	1	' following '
# 3	1	' format '
# 3	1	' forth '
# 2	1	' functions '
# 2	1	' goal '
# 2	1	' greater '
# 6	2	' gross margin '
# 2	2	' gross margin. '
# 2	2	' hear products '
# 6	1	' high '
# 3	2	' high quality '
# 6	1	' high '
# 3	2	' higher margin '
# 2	1	' historical '
# 4	2	' home car '
# 7	1	' home '
# 7	1	' including '
# 4	1	' increase '
# 4	1	' increased '
# 2	1	' increases '
# 2	1	' increasing '
# 2	1	' industry, '
# 3	1	' information '
# 3	1	' infrastructure. '
# 4	1	' installation '
# 2	1	' integration '
# 4	1	' intended '
# 4	1	' introduction '
# 2	4	' introduction significant new products. '
# 3	1	' inventory '
# 2	1	' inventory, '
# 2	1	' key '
# 2	1	' knowledge '
# 4	1	' large '
# 3	1	' larger '
# 4	1	' level '
# 3	1	' levels '
# 3	1	' leverage '
# 2	1	' likely '
# 2	3	' limited distribution products '
# 4	1	' limited '
# 2	1	' litigation '
# 6	1	' local '
# 4	1	' lower '
# 2	1	' maintaining '
# 2	1	' making '
# 4	1	' management '
# 3	1	' management, '
# 2	1	' manager, '
# 6	1	' many '
# 5	2	' many stores '
# 3	1	' market '
# 2	1	' market, '
# 2	1	' market. '
# 15	1	' marketing '
# 5	1	' markets '
# 2	1	' match '
# 2	1	' material '
# 2	1	' may '
# 2	1	' media '
# 2	1	' media, '
# 2	3	' mid highend products '
# 3	1	' miles '
# 7	1	' mix '
# 3	5	' months ended March 31, 1998 '
# 18	1	' new '
# 2	4	' new products. The Company '
# 5	2	' new stores '
# 2	1	' number '
# 5	1	' offer '
# 2	1	' offered '
# 2	1	' offering '
# 2	1	' offers '
# 5	1	' often '
# 4	1	' one '
# 8	1	' open '
# 3	3	' open new stores '
# 8	1	' open '
# 3	1	' opened '
# 5	1	' operating '
# 2	2	' operating model '
# 3	1	' opportunities '
# 3	1	' order '
# 5	1	' per '
# 2	2	' percentage revenues '
# 4	1	' percentages '
# 3	1	' performance '
# 2	1	' periods '
# 3	1	' planned '
# 5	1	' players, '
# 2	3	' portable audio equipment. '
# 6	1	' price '
# 3	1	' prices '
# 8	1	' pricing '
# 2	2	' pricing strategy, '
# 2	1	' primarily '
# 2	1	' primary '
# 2	1	' print '
# 4	1	' prior '
# 2	1	' process '
# 34	1	' product '
# 6	2	' product mix '
# 3	2	' product mix, '
# 2	3	' product mix. In '
# 34	1	' product '
# 5	2	' product sales '
# 31	1	' products '
# 8	1	' products, '
# 16	1	' products. '
# 3	3	' products. The Company '
# 7	2	' products. The '
# 6	1	' program '
# 3	1	' program, '
# 2	10	' program, customer purchases consumer electronics product one Company's stores '
# 3	2	' program. Under '
# 2	3	' program. Under program, '
# 2	1	' programs, '
# 5	1	' promotional '
# 3	1	' prototype '
# 2	1	' proven '
# 2	1	' provided '
# 5	1	' provides '
# 2	1	' providing '
# 2	1	' proximity '
# 5	1	' purchase '
# 4	1	' purchased '
# 3	1	' purchases '
# 6	1	' purchasing '
# 5	1	' quality '
# 3	1	' radio '
# 2	1	' radio, '
# 2	1	' realtime '
# 2	1	' receivers, '
# 3	1	' reduce '
# 9	1	' regional '
# 2	2	' regional markets '
# 9	1	' regional '
# 2	1	' registered '
# 3	1	' regularly '
# 3	1	' related '
# 5	1	' relationship '
# 4	2	' relationship selling '
# 4	1	' relocate '
# 2	1	' replacement '
# 2	1	' represented '
# 2	1	' reputation '
# 4	1	' results '
# 5	1	' retailers '
# 2	1	' retailers, '
# 4	1	' revenues '
# 38	1	' sales '
# 3	2	' sales associate '
# 9	2	' sales associates '
# 2	25	' sales associates receive five fifteen days additional training per year, store Company's regional training centers. The sales force receives technical product sales training prior '
# 9	2	' sales associates '
# 38	1	' sales '
# 2	2	' sales staff '
# 2	1	' satellite '
# 2	2	' screen televisions. '
# 2	1	' seek '
# 3	1	' selection '
# 6	1	' selling '
# 3	1	' serves '
# 8	1	' service '
# 5	1	' services '
# 3	1	' several '
# 2	1	' shopping '
# 4	1	' significant '
# 3	1	' similar '
# 2	6	' six months ended March 31, 1998 '
# 2	6	' six months ended March 31, 1998. '
# 6	1	' sound '
# 2	2	' sound rooms '
# 7	1	' specialty '
# 2	8	' specialty retailer high quality audio video products. The '
# 2	2	' specialty retailers '
# 3	1	' specific '
# 2	1	' staffed '
# 25	1	' store '
# 2	2	' store contribution '
# 25	1	' store '
# 2	2	' store level '
# 3	2	' store managers '
# 25	1	' store '
# 2	2	' store's '
# 2	3	' store. The Company '
# 38	1	' stores '
# 2	2	' stores display '
# 2	2	' stores within '
# 9	1	' stores, '
# 8	1	' stores. '
# 5	2	' stores. The '
# 3	3	' stores. The Company '
# 5	2	' stores. The '
# 3	1	' strategic '
# 3	1	' strategies '
# 7	1	' strategy '
# 2	1	' strategy. '
# 2	1	' strong '
# 3	1	' substantial '
# 2	1	' success '
# 2	1	' successfully '
# 2	1	' suppliers. '
# 2	2	' surround sound '
# 6	1	' system '
# 4	1	' systems '
# 2	1	' targeted '
# 5	1	' television '
# 2	23	' television wall displaying extensive selection televisions related products, many stores contain movie theater room, complete theaterstyle seats, showcases Company's home theater products. '
# 3	1	' televisions, '
# 5	1	' three '
# 3	1	' time '
# 3	1	' times '
# 2	1	' tracks '
# 8	1	' training '
# 8	1	' two '
# 2	1	' typically '
# 2	1	' value '
# 3	1	' various '
# 13	1	' video '
# 2	2	' video cassette '
# 5	2	' video products '
# 2	1	' view '
# 14	1	' within '
# 2	1	' would '
# 5	1	' year '
# 4	1	' years '
# 13	0	'" '
# 2	1	'" strategy '
# 17	0	'% '
# 2	1	'% 31% '
# 17	0	'% '
# 64	1	''s '
# 3	2	''s home '
# 64	1	''s '
# 2	1	'(1)'
# 2	1	'(2)'
# 2	1	'(3)'
# 3	1	') Includes '
# 26	0	') '
# 2	1	') implementing '
# 30	0	')'
# 3	0	'). '
# 4	1	', (ii) '
# 4	1	', (iii) '
# 3	1	', (iv) '
# 2	1	', (v) '
# 2	1	', 12 '
# 6	1	', 1998 '
# 2	1	', 1998, '
# 307	0	', '
# 21	1	', Company '
# 2	2	', Company adopted '
# 21	1	', Company '
# 2	2	', Company believes '
# 21	1	', Company '
# 2	2	', Company completed '
# 5	2	', Company's '
# 2	2	', GA 1991 '
# 3	2	', GA 1993 '
# 3	2	', GA 1995 '
# 307	0	', '
# 2	2	', MA 1983 '
# 2	2	', MD 1990 '
# 2	2	', NH 1994 '
# 2	2	', NH 1996 '
# 3	2	', PA 1997 '
# 2	1	', allows '
# 2	1	', average '
# 3	1	', comprised '
# 3	1	', customer '
# 2	1	', distribution, '
# 6	1	', including '
# 3	1	', often '
# 2	1	', product '
# 2	2	', sales associates '
# 3	1	', store '
# 322	0	','
# 3	0	'," "'
# 4	0	'," '
# 322	0	','
# 8	1	',000 '
# 4	3	',000 square feet '
# 2	3	',000 square feet, '
# 2	0	'. ('
# 146	0	'. '
# 2	2	'. Each store '
# 146	0	'. '
# 7	1	'. In '
# 3	2	'. In addition, '
# 2	5	'. Limited distribution products accounted 43% '
# 3	1	'. Most '
# 3	1	'. STORE '
# 3	3	'. See "Risk Factors '
# 2	5	'. The Automatic Price Protection program '
# 35	2	'. The Company '
# 11	3	'. The Company believes '
# 2	3	'. The Company currently '
# 35	2	'. The Company '
# 2	11	'. The Company provides new sales associates five weeks intensive classroom training, '
# 3	3	'. The Company provides '
# 35	2	'. The Company '
# 9	3	'. The Company's '
# 2	2	'. The average '
# 5	1	'. This '
# 146	0	'. '
# 2	1	'. Unlike '
# 3	0	'." '
# 153	0	'.'
