# %%
import pandas as pd
import os

# %%
## path for the location where all documents are placed
path = "C:/Users/rohit/Documents/IPO Project"
os.chdir(path)

# %%
cosinedata_df=pd.read_csv('riskfactors_cosignsimilarity.csv')

# %%
fulldata_df=pd.read_csv('ipofull_clean.csv')

# %%
merged = pd.merge(left=cosinedata_df,right=fulldata_df,how='left', left_on='CIK', right_on='cik')

# %%
merged_req=merged[['CIK','RISKFACTORS_SIMILARITY','companyname','bank','classactionfiled','classactionfiled1y','sic_category','sameday','relpc30','timetomarket','deals1year','ideals1year','revisedup','ipoyear']]

# %%
merged_req.to_excel("cosine10_similar_rf.xls")

# %%
print merged_req.columns
# Out:
# Index([u'CIK', u'RISKFACTORS_SIMILARITY', u'companyname', u'bank',
#        u'classactionfiled', u'classactionfiled1y', u'sic_category', u'sameday',
#        u'relpc30', u'timetomarket', u'deals1year', u'ideals1year',
#        u'revisedup', u'ipoyear'],
#       dtype='object')

# %%
import os
path = "C:/Users/rohit/Documents/IPO Project/mda"
os.chdir(path)
dirs = os.listdir(path)

for file in dirs:
    print file.lstrip('0')[:-8]
# Out:
# 6885
# 31347
# 46043
# 51548
# 54003
# 56679
# 70487
# 76174
# 80816
# 84581
# 101990
# 105319
# 276327
# 311407
# 316300
# 351917
# 707388
# 711065
# 712511
# 720154
# 724522
# 727489
# 732834
# 740761
# 745597
# 747201
# 748015
# 750199
# 753081
# 758540
# 758722
# 758938
# 786364
# 786998
# 787030
# 787784
# 791704
# 796735
# 797721
# 798757
# 801529
# 802967
# 805956
# 808326
# 809012
# 809248
# 809803
# 812011
# 812890
# 813562
# 814250
# 814774
# 815508
# 816066
# 817135
# 817366
# 817720
# 818813
# 820221
# 823844
# 824719
# 826075
# 827100
# 827187
# 827230
# 828064
# 828360
# 829044
# 830656
# 831529
# 831967
# 833640
# 834306
# 835887
# 836690
# 839871
# 845818
# 847935
# 849240
# 849323
# 849667
# 849869
# 850579
# 851368
# 852203
# 854418
# 855743
# 857914
# 860235
# 861878
# 862831
# 862841
# 863821
# 864559
# 866829
# 866830
# 867773
# 867889
# 870345
# 871696
# 872901
# 873538
# 874019
# 874689
# 876103
# 878436
# 878526
# 880059
# 880562
# 880765
# 881655
# 882484
# ...
